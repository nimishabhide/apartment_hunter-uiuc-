# %%
# !pip install autoscraper
# Out:
# Requirement already satisfied: autoscraper in /usr/local/lib/python3.7/dist-packages (1.1.12)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from autoscraper) (2.23.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from autoscraper) (4.2.6)
# Requirement already satisfied: bs4 in /usr/local/lib/python3.7/dist-packages (from autoscraper) (0.0.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->autoscraper) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->autoscraper) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->autoscraper) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->autoscraper) (2.10)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from bs4->autoscraper) (4.6.3)

# %%
import pandas as pd

# %%
from autoscraper import AutoScraper
questionlist=[]
scraper = AutoScraper()
url = 'https://www.apartmentfinder.com/Illinois/Champaign-Apartments'
wanted_list = ["1806 S Cottage Grove Ave, Urbana, IL 61801","$665 - $895","2 - 4 Beds","ApartmentFinder","1 Day Ago","Urbana"]
result = scraper.build(url, wanted_list)

# %%
scraper.get_result_similar("https://www.apartmentfinder.com/Illinois/Champaign-Apartments",grouped=True)
# Out:
# {'rule_2op6': ['1 - 2 Beds',
#   '1 - 4 Beds',
#   '1 - 2 Beds',
#   '2 Beds',
#   '1 - 2 Beds',
#   'Studio - 2 Beds',
#   '1 - 6 Beds',
#   '1 - 2 Beds',
#   '1 - 2 Beds',
#   '1 - 3 Beds',
#   '2 Beds',
#   '1 - 3 Beds',
#   '1 - 2 Beds',
#   '2 Beds',
#   '1 - 2 Beds',
#   '2 - 4 Beds',
#   '1 - 4 Beds',
#   '1 - 4 Beds',
#   '2 - 3 Beds',
#   '2 - 4 Beds',
#   '2 - 4 Beds',
#   '4 Beds',
#   'Studio - 3 Beds',
#   'Studio - 4 Beds',
#   '1 - 2 Beds'],
#  'rule_42g7': ['1 - 2 Beds',
#   '1 - 4 Beds',
#   '1 - 2 Beds',
#   '2 Beds',
#   '1 - 2 Beds',
#   'Studio - 2 Beds',
#   '1 - 6 Beds',
#   '1 - 2 Beds',
#   '1 - 2 Beds',
#   '1 - 3 Beds',
#   '2 Beds',
#   '1 - 3 Beds',
#   '1 - 2 Beds',
#   '2 Beds',
#   '1 - 2 Beds',
#   '2 - 4 Beds',
#   '1 - 4 Beds',
#   '1 - 4 Beds',
#   '2 - 3 Beds',
#   '2 - 4 Beds',
#   '2 - 4 Beds',
#   '4 Beds',
#   'Studio - 3 Beds',
#   'Studio - 4 Beds',
#   '1 - 2 Beds'],
#  'rule_4zff': ['Champaign',
#   'Urbana',
#   'Champaign',
#   'Urbana',
#   'Urbana',
#   'Urbana',
#   'Champaign',
#   'Champaign',
#   'Urbana',
#   'Champaign',
#   'Champaign',
#   'Champaign',
#   'Savoy',
#   'Urbana',
#   'Champaign',
#   'Urbana',
#   'Urbana',
#   'Champaign',
#   'Champaign',
#   'Champaign',
#   'Champaign',
#   'Champaign',
#   'Champaign',
#   'Champaign',
#   'Champaign'],
#  'rule_5sc4': ['8 Hrs. Ago',
#   '2 Days Ago',
#   '10 Hrs. Ago',
#   '2 Wks. Ago',
#   '2 Days Ago',
#   '8 Hrs. Ago',
#   '2 Wks. Ago',
#   '1 Day Ago',
#   '9 Hrs. Ago',
#   '1 Day Ago',
#   '1 Wk. Ago',
#   '2 Wks. Ago',
#   '2 Wks. Ago',
#   '1 Wk. Ago',
#   '2 Wks. Ago',
#   '1 Day Ago',
#   '2 Wks. Ago',
#   '1 Day Ago',
#   '2 Wks. Ago',
#   '3 Days Ago',
#   '1 Day Ago',
#   '2 Wks. Ago',
#   '2 Wks. Ago',
#   '1 Day Ago',
#   '8 Hrs. Ago'],
#  'rule_8kkl': ['1000 Baytowne Dr, Champaign, IL 61822',
#   '911 W Springfield Ave, Urbana, IL 61801',
#   '217 S Neil St, Champaign, IL 61820',
#   '1009 W Clark St, Urbana, IL 61801',
#   '530-536 E Fairlawn Dr, Urbana, IL 61801',
#   '1905 N Cunningham Ave, Urbana, IL 61802',
#   '202 E John St, Champaign, IL 61820',
#   '1712 Gentry Square Ln, Champaign, IL 61821',
#   '1032 E Kerr Ave, Urbana, IL 61801',
#   '508 E Clark St, Champaign, IL 61820',
#   '1601-1862 Valley Rd, Champaign, IL 61820',
#   '903 S 1st St, Champaign, IL 61820',
#   '1203 Wesley Ave, Savoy, IL 61874',
#   '1205 E Florida Ave, Urbana, IL 61801',
#   '1902 Karen Ct, Champaign, IL 61822',
#   '1806 S Cottage Grove Ave, Urbana, IL 61801',
#   '1306 N Lincoln Ave, Urbana, IL 61801',
#   '512 S Third St, Champaign, IL 61820',
#   '2413 N Neil St, Champaign, IL 61820',
#   '51 E John St, Champaign, IL 61820',
#   '512 E Green St, Champaign, IL 61820',
#   '1008 S 4th St, Champaign, IL 61820',
#   '310 E Springfield Ave, Champaign, IL 61820',
#   '708 S 6th St, Champaign, IL 61820',
#   '2403-2503 W Springfield Ave, Champaign, IL 61821'],
#  'rule_d296': ['Champaign',
#   'Urbana',
#   'Champaign',
#   'Urbana',
#   'Urbana',
#   'Urbana',
#   'Champaign',
#   'Champaign',
#   'Urbana',
#   'Champaign',
#   'Champaign',
#   'Champaign',
#   'Savoy',
#   'Urbana',
#   'Champaign',
#   'Urbana',
#   'Urbana',
#   'Champaign',
#   'Champaign',
#   'Champaign',
#   'Champaign',
#   'Champaign',
#   'Champaign',
#   'Champaign',
#   'Champaign'],
#  'rule_dgsv': ['Downtown Champaign',
#   'Campustown IL',
#   'Midtown Champaign',
#   'Urbana',
#   'Rantoul',
#   'Savoy',
#   'Mahomet',
#   'Tolono',
#   'Mansfield',
#   'Villa Grove',
#   'Ogden',
#   'Sidney',
#   'Thomasboro',
#   '61820',
#   '61801',
#   '61821',
#   '61822',
#   '61802',
#   '61866',
#   '61874',
#   '61853',
#   '61880',
#   '61873',
#   'Champaign County',
#   'Piatt County',
#   'University of Illinois at Urbana, Champaign',
#   'Parkland College',
#   'Studio',
#   '1 Bedroom',
#   '2 Bedroom',
#   '3 Bedroom',
#   '4 Bedroom',
#   'Income Restricted Housing',
#   'Senior Apartments',
#   'Short-Term Housing',
#   'Luxury Apartments',
#   'Cheap Apartments',
#   'Houses for Rent',
#   'Condos for Rent',
#   'Townhouses for Rent',
#   'Pet Friendly',
#   'Utilities Included',
#   'Furnished',
#   'Washer/Dryer',
#   'Lofts',
#   'Swimming Pool',
#   'Wheelchair Access',
#   'Parking',
#   'Fitness Center',
#   'Under $500',
#   'Under $600',
#   'Under $700',
#   'Under $800',
#   'Under $900',
#   'Under $1000',
#   'Under $1200',
#   'Under $1500'],
#  'rule_lf3o': ['8 Hrs. Ago',
#   '2 Days Ago',
#   '10 Hrs. Ago',
#   '2 Wks. Ago',
#   '2 Days Ago',
#   '8 Hrs. Ago',
#   '2 Wks. Ago',
#   '1 Day Ago',
#   '9 Hrs. Ago',
#   '1 Day Ago',
#   '1 Wk. Ago',
#   '2 Wks. Ago',
#   '2 Wks. Ago',
#   '1 Wk. Ago',
#   '2 Wks. Ago',
#   '1 Day Ago',
#   '2 Wks. Ago',
#   '1 Day Ago',
#   '2 Wks. Ago',
#   '3 Days Ago',
#   '1 Day Ago',
#   '2 Wks. Ago',
#   '2 Wks. Ago',
#   '1 Day Ago',
#   '8 Hrs. Ago'],
#  'rule_mdm9': ['8 Hrs. Ago',
#   '2 Days Ago',
#   '10 Hrs. Ago',
#   '2 Wks. Ago',
#   '2 Days Ago',
#   '8 Hrs. Ago',
#   '2 Wks. Ago',
#   '1 Day Ago',
#   '9 Hrs. Ago',
#   '1 Day Ago',
#   '1 Wk. Ago',
#   '2 Wks. Ago',
#   '2 Wks. Ago',
#   '1 Wk. Ago',
#   '2 Wks. Ago',
#   '1 Day Ago',
#   '2 Wks. Ago',
#   '1 Day Ago',
#   '2 Wks. Ago',
#   '3 Days Ago',
#   '1 Day Ago',
#   '2 Wks. Ago',
#   '2 Wks. Ago',
#   '1 Day Ago',
#   '8 Hrs. Ago'],
#  'rule_ni2d': ['Champaign',
#   'Urbana',
#   'Champaign',
#   'Urbana',
#   'Urbana',
#   'Urbana',
#   'Champaign',
#   'Champaign',
#   'Urbana',
#   'Champaign',
#   'Champaign',
#   'Champaign',
#   'Savoy',
#   'Urbana',
#   'Champaign',
#   'Urbana',
#   'Urbana',
#   'Champaign',
#   'Champaign',
#   'Champaign',
#   'Champaign',
#   'Champaign',
#   'Champaign',
#   'Champaign',
#   'Champaign'],
#  'rule_ouj0': ['1 - 2 Beds',
#   '1 - 4 Beds',
#   '1 - 2 Beds',
#   '2 Beds',
#   '1 - 2 Beds',
#   'Studio - 2 Beds',
#   '1 - 6 Beds',
#   '1 - 2 Beds',
#   '1 - 2 Beds',
#   '1 - 3 Beds',
#   '2 Beds',
#   '1 - 3 Beds',
#   '1 - 2 Beds',
#   '2 Beds',
#   '1 - 2 Beds',
#   '2 - 4 Beds',
#   '1 - 4 Beds',
#   '1 - 4 Beds',
#   '2 - 3 Beds',
#   '2 - 4 Beds',
#   '2 - 4 Beds',
#   '4 Beds',
#   'Studio - 3 Beds',
#   'Studio - 4 Beds',
#   '1 - 2 Beds'],
#  'rule_pgwg': ['Champaign',
#   'Urbana',
#   'Champaign',
#   'Urbana',
#   'Urbana',
#   'Urbana',
#   'Champaign',
#   'Champaign',
#   'Urbana',
#   'Champaign',
#   'Champaign',
#   'Champaign',
#   'Savoy',
#   'Urbana',
#   'Champaign',
#   'Urbana',
#   'Urbana',
#   'Champaign',
#   'Champaign',
#   'Champaign',
#   'Champaign',
#   'Champaign',
#   'Champaign',
#   'Champaign',
#   'Champaign'],
#  'rule_q444': ['8 Hrs. Ago',
#   '2 Days Ago',
#   '10 Hrs. Ago',
#   '2 Wks. Ago',
#   '2 Days Ago',
#   '8 Hrs. Ago',
#   '2 Wks. Ago',
#   '1 Day Ago',
#   '9 Hrs. Ago',
#   '1 Day Ago',
#   '1 Wk. Ago',
#   '2 Wks. Ago',
#   '2 Wks. Ago',
#   '1 Wk. Ago',
#   '2 Wks. Ago',
#   '1 Day Ago',
#   '2 Wks. Ago',
#   '1 Day Ago',
#   '2 Wks. Ago',
#   '3 Days Ago',
#   '1 Day Ago',
#   '2 Wks. Ago',
#   '2 Wks. Ago',
#   '1 Day Ago',
#   '8 Hrs. Ago'],
#  'rule_r50f': ['$865 - $1,780',
#   '$595 - $2,200',
#   '$1,160 - $1,970',
#   '$485 - $980',
#   '$775 - $840',
#   '$740 - $1,628',
#   '$650 - $2,550',
#   '$900 - $1,515',
#   '$550 - $981',
#   '$595 - $1,685',
#   '$700 - $1,050',
#   '$575 - $825',
#   '$550 - $895',
#   '$650 - $825',
#   '$625 - $845',
#   '$665 - $895',
#   '$415 - $435',
#   '$549 - $1,149',
#   '$700 - $875',
#   '$675 - $795',
#   '$709 - $925',
#   '$659 - $799',
#   '$799 - $1,519',
#   '$695 - $1,605',
#   '$665 - $885'],
#  'rule_s3uf': ['8 Hrs. Ago',
#   '2 Days Ago',
#   '10 Hrs. Ago',
#   '2 Wks. Ago',
#   '2 Days Ago',
#   '8 Hrs. Ago',
#   '2 Wks. Ago',
#   '1 Day Ago',
#   '9 Hrs. Ago',
#   '1 Day Ago',
#   '1 Wk. Ago',
#   '2 Wks. Ago',
#   '2 Wks. Ago',
#   '1 Wk. Ago',
#   '2 Wks. Ago',
#   '1 Day Ago',
#   '2 Wks. Ago',
#   '1 Day Ago',
#   '2 Wks. Ago',
#   '3 Days Ago',
#   '1 Day Ago',
#   '2 Wks. Ago',
#   '2 Wks. Ago',
#   '1 Day Ago',
#   '8 Hrs. Ago'],
#  'rule_smdb': ['Champaign',
#   'Urbana',
#   'Champaign',
#   'Urbana',
#   'Urbana',
#   'Urbana',
#   'Champaign',
#   'Champaign',
#   'Urbana',
#   'Champaign',
#   'Champaign',
#   'Champaign',
#   'Savoy',
#   'Urbana',
#   'Champaign',
#   'Urbana',
#   'Urbana',
#   'Champaign',
#   'Champaign',
#   'Champaign',
#   'Champaign',
#   'Champaign',
#   'Champaign',
#   'Champaign',
#   'Champaign'],
#  'rule_tlb8': ['Champaign',
#   'Urbana',
#   'Champaign',
#   'Urbana',
#   'Urbana',
#   'Urbana',
#   'Champaign',
#   'Champaign',
#   'Urbana',
#   'Champaign',
#   'Champaign',
#   'Champaign',
#   'Savoy',
#   'Urbana',
#   'Champaign',
#   'Urbana',
#   'Urbana',
#   'Champaign',
#   'Champaign',
#   'Champaign',
#   'Champaign',
#   'Champaign',
#   'Champaign',
#   'Champaign',
#   'Champaign'],
#  'rule_u33d': ['$865 - $1,780',
#   '$595 - $2,200',
#   '$1,160 - $1,970',
#   '$485 - $980',
#   '$775 - $840',
#   '$740 - $1,628',
#   '$650 - $2,550',
#   '$900 - $1,515',
#   '$550 - $981',
#   '$595 - $1,685',
#   '$700 - $1,050',
#   '$575 - $825',
#   '$550 - $895',
#   '$650 - $825',
#   '$625 - $845',
#   '$665 - $895',
#   '$415 - $435',
#   '$549 - $1,149',
#   '$700 - $875',
#   '$675 - $795',
#   '$709 - $925',
#   '$659 - $799',
#   '$799 - $1,519',
#   '$695 - $1,605',
#   '$665 - $885'],
#  'rule_v5y6': ['8 Hrs. Ago',
#   '2 Days Ago',
#   '10 Hrs. Ago',
#   '2 Wks. Ago',
#   '2 Days Ago',
#   '8 Hrs. Ago',
#   '2 Wks. Ago',
#   '1 Day Ago',
#   '9 Hrs. Ago',
#   '1 Day Ago',
#   '1 Wk. Ago',
#   '2 Wks. Ago',
#   '2 Wks. Ago',
#   '1 Wk. Ago',
#   '2 Wks. Ago',
#   '1 Day Ago',
#   '2 Wks. Ago',
#   '1 Day Ago',
#   '2 Wks. Ago',
#   '3 Days Ago',
#   '1 Day Ago',
#   '2 Wks. Ago',
#   '2 Wks. Ago',
#   '1 Day Ago',
#   '8 Hrs. Ago'],
#  'rule_xdjh': ['Champaign',
#   'Urbana',
#   'Champaign',
#   'Urbana',
#   'Urbana',
#   'Urbana',
#   'Champaign',
#   'Champaign',
#   'Urbana',
#   'Champaign',
#   'Champaign',
#   'Champaign',
#   'Savoy',
#   'Urbana',
#   'Champaign',
#   'Urbana',
#   'Urbana',
#   'Champaign',
#   'Champaign',
#   'Champaign',
#   'Champaign',
#   'Champaign',
#   'Champaign',
#   'Champaign',
#   'Champaign'],
#  'rule_yz6w': ['Champaign',
#   'Urbana',
#   'Champaign',
#   'Urbana',
#   'Urbana',
#   'Urbana',
#   'Champaign',
#   'Champaign',
#   'Urbana',
#   'Champaign',
#   'Champaign',
#   'Champaign',
#   'Savoy',
#   'Urbana',
#   'Champaign',
#   'Urbana',
#   'Urbana',
#   'Champaign',
#   'Champaign',
#   'Champaign',
#   'Champaign',
#   'Champaign',
#   'Champaign',
#   'Champaign',
#   'Champaign']}

# %%
scraper.set_rule_aliases({'rule_8kkl': 'Address', 'rule_r50f': 'Price','rule_2op6':'Beds','rule_q444':'Posted','rule_4zff':'Area'})
scraper.keep_rules(['rule_8kkl', 'rule_r50f','rule_2op6','rule_q444','rule_4zff'])
scraper.save('github-repository-search')

# %%
scraper.load('github-repository-search')

# %%
result=scraper.get_result_similar("https://www.apartmentfinder.com/Illinois/Champaign-Apartments/",group_by_alias=True)

# %%
d1=pd.DataFrame(result)
d1
# Out:
#                                              Address  ...       Area
# 0              1000 Baytowne Dr, Champaign, IL 61822  ...  Champaign
# 1            911 W Springfield Ave, Urbana, IL 61801  ...     Urbana
# 2                 217 S Neil St, Champaign, IL 61820  ...  Champaign
# 3                  1009 W Clark St, Urbana, IL 61801  ...     Urbana
# 4            530-536 E Fairlawn Dr, Urbana, IL 61801  ...     Urbana
# 5            1905 N Cunningham Ave, Urbana, IL 61802  ...     Urbana
# 6                 202 E John St, Champaign, IL 61820  ...  Champaign
# 7         1712 Gentry Square Ln, Champaign, IL 61821  ...  Champaign
# 8                  1032 E Kerr Ave, Urbana, IL 61801  ...     Urbana
# 9                508 E Clark St, Champaign, IL 61820  ...  Champaign
# 10          1601-1862 Valley Rd, Champaign, IL 61820  ...  Champaign
# 11                 903 S 1st St, Champaign, IL 61820  ...  Champaign
# 12                  1203 Wesley Ave, Savoy, IL 61874  ...      Savoy
# 13              1205 E Florida Ave, Urbana, IL 61801  ...     Urbana
# 14                1902 Karen Ct, Champaign, IL 61822  ...  Champaign
# 15        1806 S Cottage Grove Ave, Urbana, IL 61801  ...     Urbana
# 16              1306 N Lincoln Ave, Urbana, IL 61801  ...     Urbana
# 17               512 S Third St, Champaign, IL 61820  ...  Champaign
# 18               2413 N Neil St, Champaign, IL 61820  ...  Champaign
# 19                 51 E John St, Champaign, IL 61820  ...  Champaign
# 20               512 E Green St, Champaign, IL 61820  ...  Champaign
# 21                1008 S 4th St, Champaign, IL 61820  ...  Champaign
# 22        310 E Springfield Ave, Champaign, IL 61820  ...  Champaign
# 23                 708 S 6th St, Champaign, IL 61820  ...  Champaign
# 24  2403-2503 W Springfield Ave, Champaign, IL 61821  ...  Champaign
#
# [25 rows x 5 columns]

# %%
result1=scraper.get_result_similar("https://www.apartmentfinder.com/Illinois/Champaign-Apartments/Page5",group_by_alias=True)

# %%
d2=pd.DataFrame(result1)
d2
# Out:
#                                          Address  ...       Area
# 0            204 E Clark St, Champaign, IL 61820  ...  Champaign
# 1          201 E Armory Ave, Champaign, IL 61820  ...  Champaign
# 2              1010 W Clark St, Urbana, IL 61801  ...     Urbana
# 3           58 E Armory Ave, Champaign, IL 61820  ...  Champaign
# 4          53 E Chalmers St, Champaign, IL 61820  ...  Champaign
# 5              3 Hanover Ct, Champaign, IL 61821  ...  Champaign
# 6              1012 W Clark St, Urbana, IL 61801  ...     Urbana
# 7            506 E White St, Champaign, IL 61820  ...  Champaign
# 8       309 W Washington St, Champaign, IL 61820  ...  Champaign
# 9             1009 S 2nd St, Champaign, IL 61820  ...  Champaign
# 10         905 Springfield Ave, Urbana, IL 61801  ...     Urbana
# 11             505 S 4th St, Champaign, IL 61820  ...  Champaign
# 12           302 E Clark St, Champaign, IL 61820  ...  Champaign
# 13           314 S State St, Champaign, IL 61820  ...  Champaign
# 14           55 E Healey St, Champaign, IL 61820  ...  Champaign
# 15  2415-2435 W Bradley Ave, Champaign, IL 61821  ...  Champaign
# 16             1004 S Smith Rd, Urbana, IL 61802  ...     Urbana
# 17            104 Portsmouth Ln, Savoy, IL 61874  ...      Savoy
# 18      1507-1517 Kirby Ave, Champaign, IL 61821  ...  Champaign
# 19              100 Parkview Ln, Savoy, IL 61874  ...      Savoy
# 20         706 Inverness Rd, Champaign, IL 61822  ...  Champaign
# 21       918-1188 Pomona Dr, Champaign, IL 61822  ...  Champaign
# 22               202 N Race St, Urbana, IL 61801  ...     Urbana
# 23      610 W Marketview Dr, Champaign, IL 61820  ...  Champaign
# 24          305 E Daniel St, Champaign, IL 61820  ...  Champaign
#
# [25 rows x 5 columns]

# %%
d1=d1.append(d2)
d1
# Out:
#                                              Address  ...       Area
# 0              1000 Baytowne Dr, Champaign, IL 61822  ...  Champaign
# 1            911 W Springfield Ave, Urbana, IL 61801  ...     Urbana
# 2                 217 S Neil St, Champaign, IL 61820  ...  Champaign
# 3                  1009 W Clark St, Urbana, IL 61801  ...     Urbana
# 4            530-536 E Fairlawn Dr, Urbana, IL 61801  ...     Urbana
# 5            1905 N Cunningham Ave, Urbana, IL 61802  ...     Urbana
# 6                 202 E John St, Champaign, IL 61820  ...  Champaign
# 7         1712 Gentry Square Ln, Champaign, IL 61821  ...  Champaign
# 8                  1032 E Kerr Ave, Urbana, IL 61801  ...     Urbana
# 9                508 E Clark St, Champaign, IL 61820  ...  Champaign
# 10          1601-1862 Valley Rd, Champaign, IL 61820  ...  Champaign
# 11                 903 S 1st St, Champaign, IL 61820  ...  Champaign
# 12                  1203 Wesley Ave, Savoy, IL 61874  ...      Savoy
# 13              1205 E Florida Ave, Urbana, IL 61801  ...     Urbana
# 14                1902 Karen Ct, Champaign, IL 61822  ...  Champaign
# 15        1806 S Cottage Grove Ave, Urbana, IL 61801  ...     Urbana
# 16              1306 N Lincoln Ave, Urbana, IL 61801  ...     Urbana
# 17               512 S Third St, Champaign, IL 61820  ...  Champaign
# 18               2413 N Neil St, Champaign, IL 61820  ...  Champaign
# 19                 51 E John St, Champaign, IL 61820  ...  Champaign
# 20               512 E Green St, Champaign, IL 61820  ...  Champaign
# 21                1008 S 4th St, Champaign, IL 61820  ...  Champaign
# 22        310 E Springfield Ave, Champaign, IL 61820  ...  Champaign
# 23                 708 S 6th St, Champaign, IL 61820  ...  Champaign
# 24  2403-2503 W Springfield Ave, Champaign, IL 61821  ...  Champaign
# 0                204 E Clark St, Champaign, IL 61820  ...  Champaign
# 1              201 E Armory Ave, Champaign, IL 61820  ...  Champaign
# 2                  1010 W Clark St, Urbana, IL 61801  ...     Urbana
# 3               58 E Armory Ave, Champaign, IL 61820  ...  Champaign
# 4              53 E Chalmers St, Champaign, IL 61820  ...  Champaign
# 5                  3 Hanover Ct, Champaign, IL 61821  ...  Champaign
# 6                  1012 W Clark St, Urbana, IL 61801  ...     Urbana
# 7                506 E White St, Champaign, IL 61820  ...  Champaign
# 8           309 W Washington St, Champaign, IL 61820  ...  Champaign
# 9                 1009 S 2nd St, Champaign, IL 61820  ...  Champaign
# 10             905 Springfield Ave, Urbana, IL 61801  ...     Urbana
# 11                 505 S 4th St, Champaign, IL 61820  ...  Champaign
# 12               302 E Clark St, Champaign, IL 61820  ...  Champaign
# 13               314 S State St, Champaign, IL 61820  ...  Champaign
# 14               55 E Healey St, Champaign, IL 61820  ...  Champaign
# 15      2415-2435 W Bradley Ave, Champaign, IL 61821  ...  Champaign
# 16                 1004 S Smith Rd, Urbana, IL 61802  ...     Urbana
# 17                104 Portsmouth Ln, Savoy, IL 61874  ...      Savoy
# 18          1507-1517 Kirby Ave, Champaign, IL 61821  ...  Champaign
# 19                  100 Parkview Ln, Savoy, IL 61874  ...      Savoy
# 20             706 Inverness Rd, Champaign, IL 61822  ...  Champaign
# 21           918-1188 Pomona Dr, Champaign, IL 61822  ...  Champaign
# 22                   202 N Race St, Urbana, IL 61801  ...     Urbana
# 23          610 W Marketview Dr, Champaign, IL 61820  ...  Champaign
# 24              305 E Daniel St, Champaign, IL 61820  ...  Champaign
#
# [50 rows x 5 columns]
